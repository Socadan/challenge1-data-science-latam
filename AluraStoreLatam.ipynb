# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %% [markdown]
# #1. Análisis de facturación

# %%
# **Ingreso total por cada tienda**
total_revenue_tienda1 = tienda['Precio'].sum()
total_revenue_tienda2 = tienda2['Precio'].sum()
total_revenue_tienda3 = tienda3['Precio'].sum()
total_revenue_tienda4 = tienda4['Precio'].sum()

print(f"Total revenue for Tienda 1: {total_revenue_tienda1}")
print(f"Total revenue for Tienda 2: {total_revenue_tienda2}")
print(f"Total revenue for Tienda 3: {total_revenue_tienda3}")
print(f"Total revenue for Tienda 4: {total_revenue_tienda4}")
# Out:
# Total revenue for Tienda 1: 1150880400.0
# Total revenue for Tienda 2: 1116343500.0
# Total revenue for Tienda 3: 1098019600.0
# Total revenue for Tienda 4: 1038375700.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a list of store names and their total revenues
stores = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
total_revenues = [total_revenue_tienda1, total_revenue_tienda2, total_revenue_tienda3, total_revenue_tienda4]

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=stores, y=total_revenues, palette='viridis')
plt.title('Total Revenue by Store', fontsize=16)
plt.xlabel('Store', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-304618649.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=stores, y=total_revenues, palette='viridis')

# %%
ventas_totales = tienda['Precio'].sum() + tienda2['Precio'].sum() + tienda3['Precio'].sum() + tienda4['Precio'].sum()
print(f"Total revenue for all stores: {ventas_totales}")
# Out:
# Total revenue for all stores: 4403619200.0

# %%
partic_tienda1 = (total_revenue_tienda1 / ventas_totales) * 100
partic_tienda2 = (total_revenue_tienda2 / ventas_totales) * 100
partic_tienda3 = (total_revenue_tienda3 / ventas_totales) * 100
partic_tienda4 = (total_revenue_tienda4 / ventas_totales) * 100

print(f"Participación de Tienda 1: {partic_tienda1:.2f}%")
print(f"Participación de Tienda 2: {partic_tienda2:.2f}%")
print(f"Participación de Tienda 3: {partic_tienda3:.2f}%")
print(f"Participación de Tienda 4: {partic_tienda4:.2f}%")
# Out:
# Participación de Tienda 1: 26.13%
# Participación de Tienda 2: 25.35%
# Participación de Tienda 3: 24.93%
# Participación de Tienda 4: 23.58%

# %% [markdown]
# # 2. Ventas por categoría

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_theme(style="whitegrid")

# Function to plot sales by category for a given store
def plot_sales_by_category(df, store_name):
    plt.figure(figsize=(12, 6))
    sns.barplot(x='Cantidad de Productos', y='Categoría del Producto', data=df.sort_values('Cantidad de Productos', ascending=False), palette='viridis')
    plt.title(f'Sales by Category for {store_name}', fontsize=16)
    plt.xlabel('Number of Products Sold', fontsize=12)
    plt.ylabel('Product Category', fontsize=12)
    plt.tight_layout()
    plt.show()

# Plot for each store
plot_sales_by_category(sales_by_category_tienda1, 'Tienda 1')
plot_sales_by_category(sales_by_category_tienda2, 'Tienda 2')
plot_sales_by_category(sales_by_category_tienda3, 'Tienda 3')
plot_sales_by_category(sales_by_category_tienda4, 'Tienda 4')
# Out:
# /tmp/ipython-input-967729376.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cantidad de Productos', y='Categoría del Producto', data=df.sort_values('Cantidad de Productos', ascending=False), palette='viridis')
# /tmp/ipython-input-967729376.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cantidad de Productos', y='Categoría del Producto', data=df.sort_values('Cantidad de Productos', ascending=False), palette='viridis')
# /tmp/ipython-input-967729376.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
print("Sales by category for Tienda 1:")
display(sales_by_category_tienda1)

print("\nSales by category for Tienda 2:")
display(sales_by_category_tienda2)

print("\nSales by category for Tienda 3:")
display(sales_by_category_tienda3)

print("\nSales by category for Tienda 4:")
display(sales_by_category_tienda4)
# Out:
# Sales by category for Tienda 1:
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    171
# 1     Deportes y diversión                    284
# 2        Electrodomésticos                    312
# 3             Electrónicos                    448
# 4   Instrumentos musicales                    182
# 5                 Juguetes                    324
# 6                   Libros                    173
# 7                  Muebles                    465
# Sales by category for Tienda 2:
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    181
# 1     Deportes y diversión                    275
# 2        Electrodomésticos                    305
# 3             Electrónicos                    422
# 4   Instrumentos musicales                    224
# 5                 Juguetes                    313
# 6                   Libros                    197
# ...

# %%
all_stores_sales_by_category = pd.concat([sales_by_category_tienda1, sales_by_category_tienda2, sales_by_category_tienda3, sales_by_category_tienda4])

total_sales_by_category = all_stores_sales_by_category.groupby('Categoría del Producto')['Cantidad de Productos'].sum().sort_values(ascending=False).reset_index()

print("Total sales by category across all stores:")
display(total_sales_by_category)
# Out:
# Total sales by category across all stores:
#     Categoría del Producto  Cantidad de Productos
# 0                  Muebles                   1886
# 1             Electrónicos                   1772
# 2                 Juguetes                   1290
# 3        Electrodomésticos                   1149
# 4     Deportes y diversión                   1113
# 5   Instrumentos musicales                    753
# 6                   Libros                    742
# 7  Artículos para el hogar                    730

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# # Task
# Analyze the sales data for each store to determine the total revenue and the number of products sold by category. Identify the most popular product categories in each store. Use the files "store_a_sales.csv", "store_b_sales.csv", and "store_c_sales.csv".

# %% [markdown]
# ## Analyze sales by category for each store
#
# ### Subtask:
# Group each store's data by 'Categoría del Producto' and count the number of products in each category.

# %% [markdown]
# **Reasoning**:
# Group each store's dataframe by 'Categoría del Producto' and count the number of products in each category as instructed.

# %%
sales_by_category_tienda1 = tienda.groupby('Categoría del Producto').size().reset_index(name='Cantidad de Productos')
sales_by_category_tienda2 = tienda2.groupby('Categoría del Producto').size().reset_index(name='Cantidad de Productos')
sales_by_category_tienda3 = tienda3.groupby('Categoría del Producto').size().reset_index(name='Cantidad de Productos')
sales_by_category_tienda4 = tienda4.groupby('Categoría del Producto').size().reset_index(name='Cantidad de Productos')

display(sales_by_category_tienda1)
display(sales_by_category_tienda2)
display(sales_by_category_tienda3)
display(sales_by_category_tienda4)
# Out:
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    171
# 1     Deportes y diversión                    284
# 2        Electrodomésticos                    312
# 3             Electrónicos                    448
# 4   Instrumentos musicales                    182
# 5                 Juguetes                    324
# 6                   Libros                    173
# 7                  Muebles                    465
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    181
# 1     Deportes y diversión                    275
# 2        Electrodomésticos                    305
# 3             Electrónicos                    422
# 4   Instrumentos musicales                    224
# 5                 Juguetes                    313
# 6                   Libros                    197
# 7                  Muebles                    442
#     Categoría del Producto  Cantidad de Productos
# ...

# %% [markdown]
# ## Identify the most popular categories
#
# ### Subtask:
# For each store, find the categories with the highest sales count.

# %% [markdown]
# **Reasoning**:
# Sort each of the dataframes by 'Cantidad de Productos' in descending order and select the top row to find the most popular category for each store. Store the results in separate variables.

# %%
most_popular_tienda1 = sales_by_category_tienda1.sort_values(by='Cantidad de Productos', ascending=False).iloc[0]
most_popular_tienda2 = sales_by_category_tienda2.sort_values(by='Cantidad de Productos', ascending=False).iloc[0]
most_popular_tienda3 = sales_by_category_tienda3.sort_values(by='Cantidad de Productos', ascending=False).iloc[0]
most_popular_tienda4 = sales_by_category_tienda4.sort_values(by='Cantidad de Productos', ascending=False).iloc[0]

print("Most popular category in Tienda 1:")
display(most_popular_tienda1)
print("\nMost popular category in Tienda 2:")
display(most_popular_tienda2)
print("\nMost popular category in Tienda 3:")
display(most_popular_tienda3)
print("\nMost popular category in Tienda 4:")
display(most_popular_tienda4)
# Out:
# Most popular category in Tienda 1:
# Categoría del Producto    Muebles
# Cantidad de Productos         465
# Name: 7, dtype: object
# Most popular category in Tienda 2:
# Categoría del Producto    Muebles
# Cantidad de Productos         442
# Name: 7, dtype: object
# Most popular category in Tienda 3:
# Categoría del Producto    Muebles
# Cantidad de Productos         499
# Name: 7, dtype: object
# Most popular category in Tienda 4:
# Categoría del Producto    Muebles
# Cantidad de Productos         480
# Name: 7, dtype: object

# %% [markdown]
# ## Display the results
#
# ### Subtask:
# Print the sales count for each category in each store and list the most popular categories for each.

# %% [markdown]
# **Reasoning**:
# Print the sales count for each category and the most popular category for each store.

# %%
print("Sales by category for Tienda 1:")
display(sales_by_category_tienda1)
print("\nMost popular category in Tienda 1:")
display(most_popular_tienda1)

print("\nSales by category for Tienda 2:")
display(sales_by_category_tienda2)
print("\nMost popular category in Tienda 2:")
display(most_popular_tienda2)

print("\nSales by category for Tienda 3:")
display(sales_by_category_tienda3)
print("\nMost popular category in Tienda 3:")
display(most_popular_tienda3)

print("\nSales by category for Tienda 4:")
display(sales_by_category_tienda4)
print("\nMost popular category in Tienda 4:")
display(most_popular_tienda4)
# Out:
# Sales by category for Tienda 1:
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    171
# 1     Deportes y diversión                    284
# 2        Electrodomésticos                    312
# 3             Electrónicos                    448
# 4   Instrumentos musicales                    182
# 5                 Juguetes                    324
# 6                   Libros                    173
# 7                  Muebles                    465
# Most popular category in Tienda 1:
# Categoría del Producto    Muebles
# Cantidad de Productos         465
# Name: 7, dtype: object
# Sales by category for Tienda 2:
#     Categoría del Producto  Cantidad de Productos
# 0  Artículos para el hogar                    181
# 1     Deportes y diversión                    275
# 2        Electrodomésticos                    305
# 3             Electrónicos                    422
# 4   Instrumentos musicales                    224
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   "Muebles" (Furniture) is the most popular product category across all four stores.
# *   The sales count for "Muebles" is 465 units in Tienda 1, 442 units in Tienda 2, 499 units in Tienda 3, and 480 units in Tienda 4.
#
# ### Insights or Next Steps
#
# *   Analyze the revenue generated by each product category to understand which categories are most profitable, not just most popular by volume.
# *   Investigate the factors contributing to the high popularity of "Muebles" in all stores to leverage this trend in marketing or inventory management.

# %% [markdown]
# # Task
# Analyze revenue by category, average shipping cost per store, and average rating per store, and summarize the findings.

# %% [markdown]
# ## Analyze revenue by category
#
# ### Subtask:
# Calculate the total revenue for each product category across all stores.

# %% [markdown]
# **Reasoning**:
# Concatenate the dataframes from all four stores and then group by 'Categoría del Producto' and sum the 'Precio' to get the total revenue by category across all stores.

# %%
all_stores_revenue = pd.concat([tienda, tienda2, tienda3, tienda4])

total_revenue_by_category = all_stores_revenue.groupby('Categoría del Producto')['Precio'].sum().reset_index()

print("Total revenue by category across all stores:")
display(total_revenue_by_category)
# Out:
# Total revenue by category across all stores:
#     Categoría del Producto        Precio
# 0  Artículos para el hogar  5.757980e+07
# 1     Deportes y diversión  1.429777e+08
# 2        Electrodomésticos  1.324751e+09
# 3             Electrónicos  1.660576e+09
# 4   Instrumentos musicales  3.487726e+08
# 5                 Juguetes  7.360440e+07
# 6                   Libros  3.769610e+07
# 7                  Muebles  7.576610e+08

# %% [markdown]
# ## Analyze revenue by category
#
# ### Subtask:
# Visualize the total revenue by category using a bar chart.

# %% [markdown]
# **Reasoning**:
# Visualize the total revenue by category across all stores using a bar chart.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Categoría del Producto', y='Precio', data=total_revenue_by_category, palette='viridis')
plt.title('Total Revenue by Category Across All Stores', fontsize=16)
plt.xlabel('Product Category', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1962343640.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Categoría del Producto', y='Precio', data=total_revenue_by_category, palette='viridis')

# %% [markdown]
# ## Analyze average shipping cost per store
#
# ### Subtask:
# Calculate the average shipping cost for each store.

# %% [markdown]
# **Reasoning**:
# Calculate the average shipping cost for each store by averaging the 'Costo de envío' column in each DataFrame and store the results in separate variables. Then, print the average shipping cost for each store.

# %%
average_shipping_tienda1 = tienda['Costo de envío'].mean()
average_shipping_tienda2 = tienda2['Costo de envío'].mean()
average_shipping_tienda3 = tienda3['Costo de envío'].mean()
average_shipping_tienda4 = tienda4['Costo de envío'].mean()

print(f"Average shipping cost for Tienda 1: {average_shipping_tienda1:.2f}")
print(f"Average shipping cost for Tienda 2: {average_shipping_tienda2:.2f}")
print(f"Average shipping cost for Tienda 3: {average_shipping_tienda3:.2f}")
print(f"Average shipping cost for Tienda 4: {average_shipping_tienda4:.2f}")
# Out:
# Average shipping cost for Tienda 1: 26018.61
# Average shipping cost for Tienda 2: 25216.24
# Average shipping cost for Tienda 3: 24805.68
# Average shipping cost for Tienda 4: 23459.46

# %% [markdown]
# ## Analyze average shipping cost per store
#
# ### Subtask:
# Visualize the average shipping cost per store using a bar chart.

# %% [markdown]
# **Reasoning**:
# Visualize the average shipping cost per store using a bar chart as instructed.

# %%
stores = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
average_shipping_costs = [average_shipping_tienda1, average_shipping_tienda2, average_shipping_tienda3, average_shipping_tienda4]

plt.figure(figsize=(10, 6))
sns.barplot(x=stores, y=average_shipping_costs, palette='viridis')
plt.title('Average Shipping Cost by Store', fontsize=16)
plt.xlabel('Store', fontsize=12)
plt.ylabel('Average Shipping Cost', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2953627606.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=stores, y=average_shipping_costs, palette='viridis')

# %% [markdown]
# ## Analyze average rating per store
#
# ### Subtask:
# Calculate the average rating for each store.

# %% [markdown]
# **Reasoning**:
# Calculate the mean of the 'Calificación' column for each store's DataFrame and store the results in separate variables. Then, print the results formatted to two decimal places with descriptive labels.

# %%
average_rating_tienda1 = tienda['Calificación'].mean()
average_rating_tienda2 = tienda2['Calificación'].mean()
average_rating_tienda3 = tienda3['Calificación'].mean()
average_rating_tienda4 = tienda4['Calificación'].mean()

print(f"Average rating for Tienda 1: {average_rating_tienda1:.2f}")
print(f"Average rating for Tienda 2: {average_rating_tienda2:.2f}")
print(f"Average rating for Tienda 3: {average_rating_tienda3:.2f}")
print(f"Average rating for Tienda 4: {average_rating_tienda4:.2f}")
# Out:
# Average rating for Tienda 1: 3.98
# Average rating for Tienda 2: 4.04
# Average rating for Tienda 3: 4.05
# Average rating for Tienda 4: 4.00

# %% [markdown]
# ## Analyze average rating per store
#
# ### Subtask:
# Visualize the average rating per store using a bar chart.

# %% [markdown]
# **Reasoning**:
# Create lists of store names and average ratings, then generate and display a bar chart of the average ratings by store.

# %%
stores = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
average_ratings = [average_rating_tienda1, average_rating_tienda2, average_rating_tienda3, average_rating_tienda4]

plt.figure(figsize=(10, 6))
sns.barplot(x=stores, y=average_ratings, palette='viridis')
plt.title('Average Rating by Store', fontsize=16)
plt.xlabel('Store', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-531318506.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=stores, y=average_ratings, palette='viridis')

# %% [markdown]
# ## Summarize findings
#
# ### Subtask:
# Summarize the key findings from the revenue by category, average shipping cost per store, and average rating per store analyses.

# %% [markdown]
# **Reasoning**:
# Review the results from the previous analyses and write a summary highlighting the key observations.

# %%
print("Summary of Key Findings:")

print("\nRevenue by Category:")
display(total_revenue_by_category)
print(f"The category with the highest total revenue across all stores is: {total_revenue_by_category.iloc[0]['Categoría del Producto']} with a total revenue of {total_revenue_by_category.iloc[0]['Precio']:.2f}")

print("\nAverage Shipping Cost per Store:")
print(f"Average shipping cost for Tienda 1: {average_shipping_tienda1:.2f}")
print(f"Average shipping cost for Tienda 2: {average_shipping_tienda2:.2f}")
print(f"Average shipping cost for Tienda 3: {average_shipping_tienda3:.2f}")
print(f"Average shipping cost for Tienda 4: {average_shipping_tienda4:.2f}")
print(f"The store with the highest average shipping cost is Tienda 1 with an average cost of {average_shipping_tienda1:.2f}.")
print(f"The store with the lowest average shipping cost is Tienda 4 with an average cost of {average_shipping_tienda4:.2f}.")

print("\nAverage Rating per Store:")
print(f"Average rating for Tienda 1: {average_rating_tienda1:.2f}")
print(f"Average rating for Tienda 2: {average_rating_tienda2:.2f}")
print(f"Average rating for Tienda 3: {average_rating_tienda3:.2f}")
print(f"Average rating for Tienda 4: {average_rating_tienda4:.2f}")
print(f"The store with the highest average rating is Tienda 3 with an average rating of {average_rating_tienda3:.2f}.")
print(f"The store with the lowest average rating is Tienda 1 with an average rating of {average_rating_tienda1:.2f}.")

print("\nOverall Summary:")
print(f"The 'Electrónicos' category generated the highest total revenue across all stores. Tienda 1 had the highest average shipping cost, while Tienda 4 had the lowest. Tienda 3 received the highest average rating, and Tienda 1 had the lowest average rating.")
# Out:
# Summary of Key Findings:
#
# Revenue by Category:
#     Categoría del Producto        Precio
# 0  Artículos para el hogar  5.757980e+07
# 1     Deportes y diversión  1.429777e+08
# 2        Electrodomésticos  1.324751e+09
# 3             Electrónicos  1.660576e+09
# 4   Instrumentos musicales  3.487726e+08
# 5                 Juguetes  7.360440e+07
# 6                   Libros  3.769610e+07
# 7                  Muebles  7.576610e+08
# The category with the highest total revenue across all stores is: Artículos para el hogar with a total revenue of 57579800.00
#
# Average Shipping Cost per Store:
# Average shipping cost for Tienda 1: 26018.61
# Average shipping cost for Tienda 2: 25216.24
# Average shipping cost for Tienda 3: 24805.68
# Average shipping cost for Tienda 4: 23459.46
# The store with the highest average shipping cost is Tienda 1 with an average cost of 26018.61.
# The store with the lowest average shipping cost is Tienda 4 with an average cost of 23459.46.
#
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The "Electrónicos" category generated the highest total revenue across all stores.
# *   Tienda 1 had the highest average shipping cost (\$26,018.61), while Tienda 4 had the lowest (\$23,459.46).
# *   Tienda 3 received the highest average rating (4.05), and Tienda 1 had the lowest average rating (3.98).
#
# ### Insights or Next Steps
#
# *   Investigate the factors contributing to the high average shipping cost and low average rating in Tienda 1.
# *   Analyze the strategies employed by Tienda 3 and Tienda 4 regarding ratings and shipping costs, respectively, to identify best practices that could be implemented across all stores.
